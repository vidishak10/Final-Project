# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import keras
from keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img
from keras.applications.vgg19 import VGG19,preprocess_input,decode_predictions
# Out:
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Define the data augmentation parameters
train_datagen=ImageDataGenerator(zoom_range=0.5,shear_range=0.3,horizontal_flip=True,preprocessing_function=preprocess_input)
val_datagen=ImageDataGenerator(preprocessing_function=preprocess_input)

# Load the training and validation data
train=train_datagen.flow_from_directory(directory="Split_smol/train/",target_size=(256,256), batch_size=32)
val = val_datagen.flow_from_directory(directory="Split_smol/val/",target_size=(256,256),batch_size=32)
# Out:
# Found 697 images belonging to 9 classes.
# Found 181 images belonging to 9 classes.

# %%
# Get a sample of the training data
t_img,label=train.next()

# %%
# Plot the sample images
def plotImage(img_arr,label):
  for im,l in zip(img_arr,label):
    plt.figure(figsize=(5,5))
    plt.imshow(im)
    plt.show()

plotImage(t_img[:3],label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.layers import Dense,Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
import keras

# Load the pre-trained VGG19 model
base_model=VGG19(input_shape=(256,256,3),weights='imagenet',include_top=False)
# Out:
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# Freeze the weights of the pre-trained model
for layer in base_model.layers:
  layer.trainable=False

# %%
# Add a new classification head to the model
X=Flatten(name='flatten')(base_model.output)
X=Dense(units=9,activation='softmax',name='fc1')(X)

# Create the model
model=Model(base_model.input,X)

# %%
# Compile the model
model.compile(optimizer='adam',loss=keras.losses.categorical_crossentropy,metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Define the callbacks
from keras.callbacks import ModelCheckpoint,EarlyStopping
es=EarlyStopping(monitor='val_accuracy',min_delta=0.01,patience=3,verbose=1)
mc=ModelCheckpoint(filepath="dermenaop_model.h5",monitor='val_accuracy',min_delta=0.01,patience=3,verbose=1,save_best_only= True)
cb=[es,mc]

# %%
# Train the model
his=model.fit_generator(train,steps_per_epoch=20,epochs=30,verbose=1,callbacks=cb,validation_data=val,validation_steps=16)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2584\30562431.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   his=model.fit_generator(train,steps_per_epoch=20,epochs=30,verbose=1,callbacks=cb,validation_data=val,validation_steps=16)
# Epoch 1/30
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 20/20 [==============================] - ETA: 0s - loss: 10.1925 - accuracy: 0.4155 WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 16 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 1: val_accuracy improved from -inf to 0.65193, saving model to dermenaop_model.h5
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 20/20 [==============================] - 352s 17s/step - loss: 10.1925 - accuracy: 0.4155 - val_loss: 4.2482 - val_accuracy: 0.6519
# Epoch 2/30
# 20/20 [==============================] - ETA: 0s - loss: 4.9051 - accuracy: 0.6667 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 230s 11s/step - loss: 4.9051 - accuracy: 0.6667
# Epoch 3/30
# 20/20 [==============================] - ETA: 0s - loss: 4.0424 - accuracy: 0.6922 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 243s 11s/step - loss: 4.0424 - accuracy: 0.6922
# Epoch 4/30
# 20/20 [==============================] - ETA: 0s - loss: 3.6263 - accuracy: 0.7457WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] -
WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 300s 15s/step - loss: 1.6839 - accuracy: 0.8953
# Epoch 20/30
# 20/20 [==============================] - ETA: 0s - loss: 1.7019 - accuracy: 0.9131 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 252s 12s/step - loss: 1.7019 - accuracy: 0.9131
# Epoch 21/30
# 20/20 [==============================] - ETA: 0s - loss: 2.1500 - accuracy: 0.8973 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 233s 12s/step - loss: 2.1500 - accuracy: 0.8973
# Epoch 22/30
# 20/20 [==============================] - ETA: 0s - loss: 1.3537 - accuracy: 0.9131 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 284s 14s/step - loss: 1.3537 - accuracy: 0.9131
# Epoch 23/30
# 20/20 [==============================] - ETA: 0s - loss: 1.5945 - accuracy: 0.9084 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 252s 13s/step - loss: 1.5945 - accuracy: 0.9084
# Epoch 24/30
# 20/20 [==============================] - ETA: 0s - loss: 1.5245 - accuracy: 0.8942 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 221s 11s/step - loss: 1.5245 - accuracy: 0.8942
# Epoch 25/30
# 20/20 [==============================] - ETA: 0s - loss: 0.9903 - accuracy: 0.9258WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 186s 9s/step - loss: 0.9903 - accuracy: 0.9258
# Epoch 26/30
# 20/20 [==============================] - ETA: 0s - loss: 1.5019 - accuracy: 0.8989WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 173s 9s/step - loss: 1.5019 - accuracy: 0.8989
# Epoch 27/30
# 20/20 [==============================] - ETA: 0s - loss: 1.1478 - accuracy: 0.9194WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 184s 9s/step - loss: 1.1478 - accuracy: 0.9194
# Epoch 28/30
# 20/20 [==============================] - ETA: 0s - loss: 0.9752 - accuracy: 0.9352 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 264s 13s/step - loss: 0.9752 - accuracy: 0.9352
# Epoch 29/30
# 20/20 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.9163 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 266s 13s/step - loss: 1.1266 - accuracy: 0.9163
# Epoch 30/30
# 20/20 [==============================] - ETA: 0s - loss: 0.9529 - accuracy: 0.9336 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/20 [==============================] - 229s 11s/step - loss: 0.9529 - accuracy: 0.9336

# %%
# Evaluate the model on the validation set
acc=model.evaluate_generator(val)[1]
print(f"the accuracy of your model is {acc*100}%")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13780\1693740532.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc=model.evaluate_generator(val)[1]
# the accuracy of your model is 72.37569093704224%

# %%
# Save the model
model.save("dermenat_model.h5")

# %%
# Load the reference dictionary
ref=dict(zip(list(train.class_indices.values()),list(train.class_indices.keys())))

# %%
# Define a function to make predictions
def prediction(image_path):
     img=load_img(image_path,target_size=(256,256))
     i=img_to_array(img)
     im=preprocess_input(i)
     img=np.expand_dims(im,axis=0)
     pred=np.argmax(model.predict(img))
     print(f"the image belongs to {ref[pred]}")
     plt.imshow(i.astype(int))
     plt.axis('off')
     plt.show()

# %%
image_path = input("Enter the image path: ")
image_path = image_path.strip('"')
prediction(image_path)
# Out:
# 1/1 [==============================] - 2s 2s/step
# the image belongs to Tinea Ringworm Candidiasis
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
